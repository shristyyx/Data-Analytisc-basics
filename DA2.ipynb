# %% [markdown]
# Experiment 2 : To study different packages available for data science

# %%
# importing dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# plotting a random graph with numpy arrays 
xaxisPoints = np.array([0,10])  # [0,1,...,9,10]
yaxisPoints = np.array([0,200])  # [0,1,...,198,199,200]
plt.plot(xaxisPoints, yaxisPoints)
plt.show()

# %%
# plotting random graph with arrays 
plt.plot([1,2,3], [4,2,3])
plt.show()
